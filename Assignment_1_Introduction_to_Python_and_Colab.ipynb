# %% [markdown]
# <a href="https://colab.research.google.com/github/prudence-ayivi/BRICS-Astro/blob/main/Assignment_1_Introduction_to_Python_and_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prudence AYIVI
#
# Sirius Space Association
#
# Benin

# %%
print("Hello, BRICS Astronomy")
# Out:
# Hello, BRICS Astronomy
